# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("ReLU_skip/results/rec_rate_skip_n200_d100_w0_X0_sample5.npy")

# %%
fig, ax = plt.subplots()
xx, yy = np.meshgrid(np.arange(10, 200+1, 10), np.arange(10, 100+1, 10))
contours = ax.contourf(xx, yy, data.mean(axis=2).T)
fig.colorbar(contours)
ax.set_xlabel("n")
ax.set_ylabel("d")

plt.show()

# %%
# %%
from ReLU_skip.rec_rate_skip import solve_problem

# %%
data = solve_problem(1000, 5, 1)

# %%
data

# %%
np.sort(np.round(np.linalg.norm(data['opt_w'], axis=0), 2))

# %%
data['opt_w'][:, -1]
